# %%
import os

data_dir = "/home/user/Workspaces/python-machine-learning/cell_images"
os.listdir(data_dir)
# Out:
# ['train', 'test']

# %% [markdown]
# # CNN: (1) Reading the Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from matplotlib.image import imread
# Out:
# /home/user/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
test_path = data_dir + "/test/"
train_path = data_dir + "/train/"

# %%
os.listdir(test_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(train_path)
# Out:
# ['parasitized', 'uninfected']

# %%
os.listdir(train_path + 'parasitized')[0]
# Out:
# 'C82P43ThinF_IMG_20150817_124728_cell_26.png'

# %%
para_cell = train_path + "parasitized/" + "C82P43ThinF_IMG_20150817_124728_cell_26.png"
plt.imshow(imread(para_cell))

# %%
os.listdir(train_path + "uninfected")
# Out:
# ['C149P110ThinF_IMG_20151115_114629_cell_75.png',
#  'C173P134NThinF_IMG_20151130_115733_cell_194.png',
#  'C188P149ThinF_IMG_20151203_134229_cell_44.png',
#  'C2NThinF_IMG_20150604_114815_cell_95.png',
#  'C237ThinF_IMG_20151127_104748_cell_152.png',
#  'C85P46ThinF_IMG_20150820_105154_cell_200.png',
#  'C48P9thinF_IMG_20150721_160944_cell_53.png',
#  'C171P132ThinF_IMG_20151119_153851_cell_71.png',
#  'C86P47ThinF_IMG_20150820_125057_cell_173.png',
#  'C232ThinF_IMG_20151112_154211_cell_71.png',
#  'C229ThinF_IMG_20151112_144222_cell_182.png',
#  'C152P113ThinF_IMG_20151115_124853_cell_39.png',
#  'C60P21thinF_IMG_20150803_144003_cell_81.png',
#  'C64P25N_ThinF_IMG_20150818_153401_cell_70.png',
#  'C214ThinF_IMG_20151106_115440_cell_187.png',
#  'C149P110ThinF_IMG_20151115_114910_cell_7.png',
#  'C150P111ThinF_IMG_20151115_115950_cell_47.png',
#  'C222ThinF_IMG_20151115_151433_cell_104.png',
#  'C189P150ThinF_IMG_20151203_141719_cell_11.png',
#  'C238NThinF_IMG_20151207_114914_cell_190.png',
#  'C45P6ThinF_IMG_20151130_154725_cell_113.png',
#  'C46P7ThinF_IMG_20151130_205558_cell_66.png',
#  'C223ThinF_IMG_20151112_104410_cell_209.png',
#  'C235ThinF_IMG_20151112_164723_cell_275.png',
#  'C2NThinF_IMG_20150604_114815_cell_73.png',
#  'C52P13thinF_IMG_20150725_125847_cell_104.png',
#  'C147P108ThinF_IMG_20151115_092605_cell_221.png',
#  'C74P35_ThinF_IMG_20150815_114819_cell_42.png',
#  'C114P75ThinF_IMG_20150930_150145_cell_154.png',
#  'C5NThinF_IMG_20150609_122108_cell_117.png',
#  'C221ThinF_IMG_20151106_160727_cell_84.png',
#  'C208ThinF_IMG_20151029_155827_cell_197.png',
#  'C53P14thinF_IMG_20150726_114439_cell_27.png',
#  'C125P86ThinF_IMG_20151004_102132_cell_116.png',
#  'C49P10thinF_IMG_20150724_102951_cell_66.png',
#  'C131P92ThinF_IMG_20151004_151126_cell_80.png',
#  'C59P20thinF_IMG_20150803_112733_cell_72.png',
#  'C39P4thinF_original_IMG_20150622_105253_cell_89.png',
#  'C6NThinF_IMG_20150609_121955_cell_51.png',
#  'C106P67ThinF_IMG_20150924_103636_cell_149.png',
#  'C89P50ThinF_IMG_20150820_162300_cell_108.png',
#  'C61P22N_ThinF_IMG_20150818_112811_cell_234.png',
#  'C105P66ThinF_IMG_20150924_094800_cell_63.png',
#  'C162P123ThinF_IMG_20151116_104451_cell_14.png',
#  'C164P125ThinF_IMG_20151116_113651_cell_24.png',
#  'C177P138NThinF_IMG_20151201_144820_cell_42.png',
#  'C114P75ThinF_IMG_20150930_150145_cell_40.png',
#  'C154P115ThinF_IMG_20151115_141837_cell_108.png',
#  'C241NThinF_IMG_20151207_124358_cell_35.png',
#  'C75P36_ThinF_IMG_20150815_163707_cell_155.png',
#  'C13NThinF_IMG_20150614_131529_cell_241.png',
#  'C76P37ThinF_IMG_20150815_173019_cell_52.png',
#  'C1_thinF_IMG_20150604_104919_cell_84.png',
#  'C47P8thin_Original_Motic_IMG_20150714_093715_cell_76.png',
#  'C203ThinF_IMG_20151029_104112_cell_86.png',
#  'C203ThinF_IMG_20151029_110105_cell_98.png',
#  'C236ThinF_IMG_20151127_102115_cell_219.png',
#  'C75P36_ThinF_IMG_20150815_163225_cell_164.png',
#  'C110P71ThinF_IMG_20150930_105319_cell_137.png',
#  'C187P148NThinF_IMG_20151203_153410_cell_114.png',
#  'C95P56ThinF_IMG_20150821_172222_cell_22.png',
#  'C213ThinF_IMG_20151106_112422_cell_168.png',
#  'C69P30N_ThinF_IMG_20150819_135705_cell_155.png',
#  'C70P31_ThinF_IMG_20150819_142744_cell_51.png',
#  'C176P137NThinF_IMG_20151201_122708_cell_22.png',
#  'C54P15thinF_IMG_20150728_113006_cell_23.png',
#  'C33P1thinF_IMG_20150619_120742a_cell_155.png',
#  'C140P101ThinF_IMG_20151005_210026_cell_49.png',
#  'C184P145ThinF_IMG_20151203_102543_cell_4.png',
#  'C47P8thin_Original_Motic_IMG_20150714_094054_cell_63.png',
#  'C236ThinF_IMG_20151127_102428_cell_126.png',
#  'C185P146ThinF_IMG_20151203_110448_cell_243.png',
#  'C148P109ThinF_IMG_20151115_112333_cell_167.png',
#  'C55P16thinF_IMG_20150728_123154_cell_122.png',
#  'C184P145ThinF_IMG_20151203_102543_cell_13.png',
#  'C105P66ThinF_IMG_20150924_095913_cell_98.png',
#  'C152P113ThinF_IMG_20151115_125038_cell_37.png',
#  'C228ThinF_IMG_20151112_142900_cell_144.png',
#  'C139P100ThinF_IMG_20151005_183338_cell_45.png',
#  'C117P78ThinF_IMG_20150930_214317_cell_55.png',
#  'C141P102ThinF_IMG_20151005_214208_cell_57.png',
#  'C115P76ThinF_IMG_20150930_161825_cell_167.png',
#  'C81P42ThinF_IMG_20150817_115942_cell_144.png',
#  'C237ThinF_IMG_20151127_105320_cell_11.png',
#  'C65P26N_ThinF_IMG_20150818_154436_cell_1.png',
#  'C204ThinF_IMG_20151029_112231_cell_111.png',
#  'C203ThinF_IMG_20151029_110105_cell_162.png',
#  'C168P129ThinF_IMG_20151118_153739_cell_70.png',
#  'C141P102ThinF_IMG_20151005_214338_cell_23.png',
#  'C219ThinF_IMG_20151106_150135_cell_98.png',
#  'C159P120ThinF_IMG_20151115_190812_cell_16.png',
#  'C239ThinF_IMG_20151127_113150_cell_225.png',
#  'C163P124ThinF_IMG_20151116_110818_cell_205.png',
#  'C224ThinF_IMG_20151112_113157_cell_239.png',
#  'C241NThinF_IMG_20151207_124115_cell_138.png',
#  'C74P35_ThinF_IMG_20150815_114555_cell_53.png',
#  'C124P85ThinF_IMG_20151002_155223_cell_116.png',
#  'C113P74ThinF_IMG_20150930_134751_cell_87.png',
#  'C169P130ThinF_IMG_20151119_144354_cell_228.png',
#  'C158P119ThinF_IMG_20151115_183157_cell_121.png',
#  'C211ThinF_IMG_20151029_163959_cell_42.png',
#  'C207ThinF_IMG_20151029_144152_cell_222.png',
#  'C169P130ThinF_IMG_20151119_143039_cell_148.png',
#  'C105P66ThinF_IMG_20150924_094800_cell_70.png',
#  'C124P85ThinF_IMG_20151002_155101_cell_9.png',
#  'C112P73ThinF_IMG_20150930_131900_cell_46.png',
#  'C152P113ThinF_IMG_20151115_125038_cell_11.png',
#  'C46P7ThinF_IMG_20151130_210309_cell_95.png',
#  'C216ThinF_IMG_20151106_134733_cell_65.png',
#  'C212ThinF_IMG_20151106_110230_cell_266.png',
#  'C225ThinF_IMG_20151112_113915_cell_271.png',
#  'C145P106ThinF_IMG_20151016_154921_cell_10.png',
#  'C165P126ThinF_IMG_20151117_172356_cell_166.png',
#  'C213ThinF_IMG_20151106_112759_cell_148.png',
#  'C184P145ThinF_IMG_20151203_103824_cell_68.png',
#  'C126P87ThinF_IMG_20151004_104728_cell_42.png',
#  'C188P149ThinF_IMG_20151203_134449_cell_92.png',
#  'C61P22N_ThinF_IMG_20150818_112704_cell_210.png',
#  'C139P100ThinF_IMG_20151005_182822_cell_147.png',
#  'C141P102ThinF_IMG_20151005_214033_cell_83.png',
#  'C104P65ThinF_IMG_20150918_172214_cell_27.png',
#  'C204ThinF_IMG_20151029_112231_cell_87.png',
#  'C111P72ThinF_IMG_20150930_113210_cell_18.png',
#  'C80P41ThinF_IMG_20150817_111544_cell_6.png',
#  'C52P13thinF_IMG_20150725_123938_cell_179.png',
#  'C153P114ThinF_IMG_20151115_140242_cell_17.png',
#  'C235ThinF_IMG_20151112_165055_cell_238.png',
#  'C71P32_ThinF_IMG_20150813_163120_cell_88.png',
#  'C171P132ThinF_IMG_20151119_153347_cell_70.png',
#  'C201ThinF_IMG_20150930_142848_cell_179.png',
#  'C7NthinF_IMG_20150611_104510_cell_54.png',
#  'C169P130ThinF_IMG_20151118_163539_cell_52.png',
#  'C134P95ThinF_IMG_20151005_121343_cell_119.png',
#  'C225ThinF_IMG_20151112_113836_cell_148.png',
#  'C45P6ThinF_IMG_20151130_154725_cell_74.png',
#  'C13NThinF_IMG_20150614_131617_cell_99.png',
#  'C129P90ThinF_IMG_20151004_133921_cell_97.png',
#  'C38P3thinF_original_IMG_20150621_112023_cell_69.png',
#  'C123P84ThinF_IMG_20151002_152330_cell_165.png',
#  'C98P59ThinF_IMG_20150917_153938_cell_26.png',
#  'C203ThinF_IMG_20151029_110105_cell_61.png',
#  'C152P113ThinF_IMG_20151115_124557_cell_116.png',
#  'C39P4thinF_original_IMG_20150622_105102_cell_73.png',
#  'C208ThinF_IMG_20151029_151017_cell_57.png',
#  'C205ThinF_IMG_20151106_151800_cell_38.png',
#  'C100P61ThinF_IMG_20150918_145042_cell_5.png',
#  'C48P9thinF_IMG_20150721_161243_cell_65.png',
#  'C42P5thin_original_IMG_20150623_134919_cell_55.png',
#  'C67P28N_ThinF_IMG_20150819_133000_cell_53.png',
#  'C110P71ThinF_IMG_20150930_105925_cell_40.png',
#  'C130P91ThinF_IMG_20151004_142709_cell_101.png',
#  'C177P138NThinF_IMG_20151201_144820_cell_137.png',
#  'C170P131ThinF_IMG_20151119_115918_cell_198.png',
#  'C229ThinF_IMG_20151112_144534_cell_45.png',
#  'C129P90ThinF_IMG_20151004_133538_cell_9.png',
#  'C130P91ThinF_IMG_20151004_141825_cell_82.png',
#  'C238NThinF_IMG_20151207_114038_cell_97.png',
#  'C147P108ThinF_IMG_20151115_101156_cell_29.png',
#  'C163P124ThinF_IMG_20151116_111147_cell_61.png',
#  'C214ThinF_IMG_20151106_114526_cell_44.png',
#  'C128P89ThinF_IMG_20151004_131129_cell_121.png',
#  'C85P46ThinF_IMG_20150820_105748_cell_128.png',
#  'C65P26N_ThinF_IMG_20150818_154050_cell_160.png',
#  'C52P13thinF_IMG_20150725_125847_cell_125.png',
#  'C151P112ThinF_IMG_20151115_121644_cell_110.png',
#  'C113P74ThinF_IMG_20150930_134949_cell_108.png',
#  'C113P74ThinF_IMG_20150930_135904_cell_60.png',
#  'C228ThinF_IMG_20151112_142900_cell_4.png',
#  'C105P66ThinF_IMG_20150924_094944_cell_72.png',
#  'C149P110ThinF_IMG_20151115_114729_cell_23.png',
#  'C152P113ThinF_IMG_20151115_123837_cell_118.png',
#  'C61P22N_ThinF_IMG_20150818_112433_cell_7.png',
#  'C102P63ThinF_IMG_20150918_162051_cell_79.png',
#  'C59P20thinF_IMG_20150803_112858_cell_16.png',
#  'C238NThinF_IMG_20151207_114444_cell_41.png',
#  'C106P67ThinF_IMG_20150924_102245_cell_76.png',
#  'C174P135NThinF_IMG_20151127_135554_cell_125.png',
#  'C6NThinF_IMG_20150609_122327_cell_112.png',
#  'C126P87ThinF_IMG_20151004_104441_cell_43.png',
#  'C225ThinF_IMG_20151112_113836_cell_6.png',
#  'C65P26N_ThinF_IMG_20150818_154714_cell_173.png',
#  'C67P28N_ThinF_IMG_20150819_132441_cell_114.png',
#  'C211ThinF_IMG_20151029_164033_cell_261.png',
#  'C70P31_ThinF_IMG_20150813_130510_cell_43.png',
#  'C241NThinF_IMG_20151207_124608_cell_61.png',
#  'C112P73ThinF_IMG_20150930_131605_cell_142.png',
#  'C110P71ThinF_IMG_20150930_110404_cell_13.png',
#  'C77P38ThinF_IMG_20150601_155642_cell_76.png',
#  'C128P89ThinF_IMG_20151004_131753_cell_99.png',
#  'C160P121ThinF_IMG_20151116_092925_cell_44.png',
#  'C84P45ThinF_IMG_20150818_101412_cell_32.png',
#  'C92P53ThinF_IMG_20150821_150457_cell_97.png',
#  'C153P114ThinF_IMG_20151115_135832_cell_236.png',
#  'C212ThinF_IMG_20151106_110411_cell_179.png',
#  'C101P62ThinF_IMG_20150918_151006_cell_8.png',
#  'C140P101ThinF_IMG_20151005_210309_cell_103.png',
#  'C62P23N_ThinF_IMG_20150818_133307_cell_48.png',
#  'C2NThinF_IMG_20150604_115238_cell_133.png',
#  'C151P112ThinF_IMG_20151115_121644_cell_51.png',
#  'C225ThinF_IMG_20151112_113915_cell_165.png',
#  'C103P64ThinF_IMG_20150918_165125_cell_132.png',
#  'C156P117ThinF_IMG_20151115_154435_cell_192.png',
#  'C183P144NThinF_IMG_20151201_223357_cell_132.png',
#  'C222ThinF_IMG_20151115_151015_cell_55.png',
#  'C229ThinF_IMG_20151112_144613_cell_1.png',
#  'C74P35_ThinF_IMG_20150815_113951_cell_91.png',
#  'C126P87ThinF_IMG_20151004_105342_cell_16.png',
#  'C50P11thinF_IMG_20150724_120716_cell_111.png',
#  'C132P93ThinF_IMG_20151004_152257_cell_65.png',
#  'C238NThinF_IMG_20151207_114605_cell_171.png',
#  'C182P143NThinF_IMG_20151201_172524_cell_26.png',
#  'C96P57ThinF_IMG_20150824_105445_cell_29.png',
#  'C63P24N_ThinF_IMG_20150818_144456_cell_116.png',
#  'C217ThinF_IMG_20151106_141326_cell_155.png',
#  'C138P99ThinF_IMG_20151005_173241_cell_65.png',
#  'C146P107ThinF_IMG_20151018_134554_cell_101.png',
#  'C203ThinF_IMG_20151029_102123_cell_24.png',
#  'C57P18thinF_IMG_20150729_111518_cell_53.png',
#  'C174P135NThinF_IMG_20151127_135311_cell_122.png',
#  'C205ThinF_IMG_20151106_151711_cell_153.png',
#  'C216ThinF_IMG_20151106_135653_cell_199.png',
#  'C117P78ThinF_IMG_20150930_214317_cell_20.png',
#  'C150P111ThinF_IMG_20151115_120244_cell_161.png',
#  'C123P84ThinF_IMG_20151002_151432_cell_70.png',
#  'C95P56ThinF_IMG_20150821_171242_cell_21.png',
#  'C173P134NThinF_IMG_20151130_115733_cell_184.png',
#  'C184P145ThinF_IMG_20151203_103824_cell_37.png',
#  'C53P14thinF_IMG_20150726_114439_cell_170.png',
#  'C110P71ThinF_IMG_20150930_105319_cell_5.png',
#  'C119P80ThinF_IMG_20151002_124345_cell_103.png',
#  'C42P5thin_original_IMG_20150623_134547_cell_155.png',
#  'C165P126ThinF_IMG_20151117_164432_cell_140.png',
#  'C84P45ThinF_IMG_20150818_101412_cell_95.png',
#  'C61P22N_ThinF_IMG_20150818_112626_cell_147.png',
#  'C105P66ThinF_IMG_20150924_095034_cell_112.png',
#  'C133P94ThinF_IMG_20151004_155721_cell_103.png',
#  'C205ThinF_IMG_20151106_151514_cell_152.png',
#  'C12NThinF_IMG_20150614_124212_cell_73.png',
#  'C215ThinF_IMG_20151106_133643_cell_1.png',
#  'C152P113ThinF_IMG_20151115_125038_cell_29.png',
#  'C126P87ThinF_IMG_20151004_105100_cell_111.png',
#  'C117P78ThinF_IMG_20150930_221048_cell_85.png',
#  'C111P72ThinF_IMG_20150930_112827_cell_41.png',
#  'C232ThinF_IMG_20151112_154251_cell_56.png',
#  'C147P108ThinF_IMG_20151115_103432_cell_170.png',
#  'C95P56ThinF_IMG_20150821_172607_cell_82.png',
#  'C143P104ThinF_IMG_20151005_225413_cell_167.png',
#  'C37BP2_thinF_IMG_20150620_132440a_cell_1.png',
#  'C182P143NThinF_IMG_20151201_171836_cell_109.png',
#  'C201ThinF_IMG_20150930_143544_cell_115.png',
#  'C230ThinF_IMG_20151112_150753_cell_227.png',
#  'C220ThinF_IMG_20151106_154016_cell_1.png',
#  'C189P150ThinF_IMG_20151203_142224_cell_3.png',
#  'C230ThinF_IMG_20151112_150647_cell_56.png',
#  'C167P128ReThinF_IMG_20151201_105354_cell_160.png',
#  'C74P35_ThinF_IMG_20150815_114401_cell_40.png',
#  'C140P101ThinF_IMG_20151005_211530_cell_64.png',
#  'C153P114ThinF_IMG_20151115_135911_cell_59.png',
#  'C69P30N_ThinF_IMG_20150819_135705_cell_141.png',
#  'C220ThinF_IMG_20151106_153947_cell_16.png',
#  'C131P92ThinF_IMG_20151004_151001_cell_116.png',
#  'C48P9thinF_IMG_20150721_161243_cell_9.png',
#  'C7NthinF_IMG_20150611_104753_cell_57.png',
#  'C75P36_ThinF_IMG_20150815_163015_cell_40.png',
#  'C220ThinF_IMG_20151106_154339_cell_12.png',
#  'C62P23N_ThinF_IMG_20150818_133055_cell_85.png',
#  'C158P119ThinF_IMG_20151115_181859_cell_108.png',
#  'C239ThinF_IMG_20151127_113008_cell_162.png',
#  'C208ThinF_IMG_20151029_155554_cell_116.png',
#  'C210ThinF_IMG_20151029_162834_cell_86.png',
#  'C86P47ThinF_IMG_20150820_123717_cell_170.png',
#  'C76P37ThinF_IMG_20150815_171214_cell_69.png',
#  'C217ThinF_IMG_20151106_141649_cell_225.png',
#  'C210ThinF_IMG_20151029_162834_cell_32.png',
#  'C238NThinF_IMG_20151207_114653_cell_58.png',
#  'C181P142ThinF_IMG_20151127_155914_cell_45.png',
#  'C86P47ThinF_IMG_20150820_123717_cell_190.png',
#  'C88P49ThinF_IMG_20150820_153042_cell_155.png',
#  'C214ThinF_IMG_20151106_114526_cell_208.png',
#  'C116P77ThinF_IMG_20150930_171954_cell_67.png',
#  'C82P43ThinF_IMG_20150817_123824_cell_107.png',
#  'C201ThinF_IMG_20150930_143544_cell_18.png',
#  'C220ThinF_IMG_20151106_154533_cell_118.png',
#  'C118P79ThinF_IMG_20151002_110834_cell_23.png',
#  'C238NThinF_IMG_20151207_114605_cell_24.png',
#  'C42P5thin_original_IMG_20150623_135746_cell_128.png',
#  'C225ThinF_IMG_20151112_113836_cell_18.png',
#  'C220ThinF_IMG_20151106_154016_cell_127.png',
#  'C81P42ThinF_IMG_20150817_120351_cell_142.png',
#  'C240ThinF_IMG_20151127_115247_cell_160.png',
#  'C224ThinF_IMG_20151112_112334_cell_166.png',
#  'C176P137NThinF_IMG_20151201_121808_cell_85.png',
#  'C168P129ThinF_IMG_20151118_160845_cell_123.png',
#  'C181P142ThinF_IMG_20151127_160650_cell_31.png',
#  'C58P19thinF_IMG_20150802_122215_cell_89.png',
#  'C161P122ThinF_IMG_20151116_101403_cell_45.png',
#  'C52P13thinF_IMG_20150725_125213_cell_122.png',
#  'C169P130ThinF_IMG_20151119_144354_cell_139.png',
#  'C13NThinF_IMG_20150614_131617_cell_117.png',
#  'C3thin_original_IMG_20150608_163029_cell_220.png',
#  'C211ThinF_IMG_20151029_164451_cell_213.png',
#  'C99P60ThinF_IMG_20150918_141001_cell_46.png',
#  'C164P125ThinF_IMG_20151116_120135_cell_46.png',
#  'C158P119ThinF_IMG_20151115_181136_cell_124.png',
#  'C210ThinF_IMG_20151029_162439_cell_259.png',
#  'C232ThinF_IMG_20151112_154719_cell_1.png',
#  'C83P44ThinF_IMG_20150817_134331_cell_122.png',
#  'C33P1thinF_IMG_20150619_121435a_cell_41.png',
#  'C167P128ReThinF_IMG_20151201_110011_cell_143.png',
#  'C127P88ThinF_IMG_20151004_112301_cell_49.png',
#  'C73P34_ThinF_IMG_20150815_111422_cell_22.png',
#  'C76P37ThinF_IMG_20150815_171454_cell_2.png',
#  'C46P7ThinF_IMG_20151130_205828_cell_99.png',
#  'C73P34_ThinF_IMG_20150815_112246_cell_12.png',
#  'C68P29N_ThinF_IMG_20150819_133236_cell_64.png',
#  'C128P89ThinF_IMG_20151004_130810_cell_50.png',
#  'C139P100ThinF_IMG_20151005_183601_cell_143.png',
#  'C176P137NThinF_IMG_20151201_122811_cell_23.png',
#  'C166P127ThinF_IMG_20151117_194147_cell_197.png',
#  'C74P35_ThinF_IMG_20150815_114153_cell_72.png',
#  'C50P11thinF_IMG_20150724_115749_cell_74.png',
#  'C2NThinF_IMG_20150604_115238_cell_115.png',
#  'C45P6ThinF_IMG_20151130_160241_cell_78.png',
#  'C187P148NThinF_IMG_20151203_152841_cell_75.png',
#  'C80P41ThinF_IMG_20150817_110608_cell_138.png',
#  'C151P112ThinF_IMG_20151115_121843_cell_66.png',
#  'C209ThinF_IMG_20151029_160857_cell_219.png',
#  'C71P32_ThinF_IMG_20150813_163655_cell_58.png',
#  'C70P31_ThinF_IMG_20150819_141403_cell_82.png',
#  'C187P148NThinF_IMG_20151203_153713_cell_140.png',
#  'C60P21thinF_IMG_20150804_113602_cell_12.png',
#  'C88P49ThinF_IMG_20150820_153042_cell_146.png',
#  'C135P96ThinF_IMG_20151005_123857_cell_158.png',
#  'C110P71ThinF_IMG_20150930_105319_cell_94.png',
#  'C4thin_original_IMG_20150608_165620_cell_161.png',
#  'C208ThinF_IMG_20151029_160108_cell_59.png',
#  'C214ThinF_IMG_20151106_131748_cell_148.png',
#  'C221ThinF_IMG_20151106_160653_cell_104.png',
#  'C147P108ThinF_IMG_20151115_101317_cell_123.png',
#  'C142P103ThinF_IMG_20151005_223257_cell_80.png',
#  'C165P126ThinF_IMG_20151117_164432_cell_130.png',
#  'C76P37ThinF_IMG_20150815_173019_cell_53.png',
#  'C128P89ThinF_IMG_20151004_131129_cell_93.png',
#  'C185P146ThinF_IMG_20151203_111121_cell_24.png',
#  'C231ThinF_IMG_20151112_153147_cell_100.png',
#  'C229ThinF_IMG_20151112_144652_cell_198.png',
#  'C78P39ThinF_IMG_20150606_104936_cell_13.png',
#  'C156P117ThinF_IMG_20151115_153831_cell_84.png',
#  'C133P94ThinF_IMG_20151004_155721_cell_49.png',
#  'C105P66ThinF_IMG_20150924_100655_cell_64.png',
#  'C81P42ThinF_IMG_20150817_120524_cell_36.png',
#  'C3thin_original_IMG_20150608_163047_cell_168.png',
#  'C123P84ThinF_IMG_20151002_151432_cell_38.png',
#  'C50P11thinF_IMG_20150724_115603_cell_72.png',
#  'C83P44ThinF_IMG_20150817_133454_cell_61.png',
#  'C6NThinF_IMG_20150609_122832_cell_89.png',
#  'C119P80ThinF_IMG_20151002_123043_cell_67.png',
#  'C76P37ThinF_IMG_20150815_171454_cell_226.png',
#  'C149P110ThinF_IMG_20151115_114555_cell_212.png',
#  'C170P131ThinF_IMG_20151119_120150_cell_104.png',
#  'C208ThinF_IMG_20151029_155554_cell_151.png',
#  'C109P70ThinF_IMG_20150930_102944_cell_152.png',
#  'C98P59ThinF_IMG_20150917_153938_cell_117.png',
#  'C187P148NThinF_IMG_20151203_154111_cell_77.png',
#  'C13NThinF_IMG_20150614_131457_cell_35.png',
#  'C68P29N_ThinF_IMG_20150819_134112_cell_51.png',
#  'C97P58ThinF_IMG_20150917_151320_cell_113.png',
#  'C1_thinF_IMG_20150604_105100_cell_69.png',
#  'C37BP2_thinF_IMG_20150620_132847a_cell_60.png',
#  'C104P65ThinF_IMG_20150918_170850_cell_32.png',
#  'C221ThinF_IMG_20151106_160727_cell_207.png',
#  'C175P136NThinF_IMG_20151127_141325_cell_32.png',
#  'C108P69ThinF_IMG_20150924_224616_cell_14.png',
#  'C62P23N_ThinF_IMG_20150818_133055_cell_102.png',
#  'C236ThinF_IMG_20151127_102516_cell_146.png',
#  'C85P46ThinF_IMG_20150820_105748_cell_49.png',
#  'C166P127ThinF_IMG_20151117_194410_cell_176.png',
#  'C57P18thinF_IMG_20150729_110134_cell_138.png',
#  'C132P93ThinF_IMG_20151004_151811_cell_37.png',
#  'C79P40ThinF_IMG_20150817_102823_cell_107.png',
#  'C38P3thinF_original_IMG_20150621_112138_cell_111.png',
#  'C49P10thinF_IMG_20150724_102330_cell_219.png',
#  'C177P138NThinF_IMG_20151201_141604_cell_135.png',
#  'C141P102ThinF_IMG_20151005_214338_cell_53.png',
#  'C147P108ThinF_IMG_20151115_103432_cell_117.png',
#  'C232ThinF_IMG_20151112_154345_cell_276.png',
#  'C176P137NThinF_IMG_20151201_121303_cell_57.png',
#  'C183P144NThinF_IMG_20151201_223357_cell_120.png',
#  'C97P58ThinF_IMG_20150917_150838_cell_118.png',
#  'C186P147NThinF_IMG_20151203_150222_cell_54.png',
#  'C7NthinF_IMG_20150611_104404_cell_44.png',
#  'C181P142ThinF_IMG_20151127_155722_cell_51.png',
#  'C42P5thin_original_IMG_20150623_135746_cell_126.png',
#  'C42P5thin_original_IMG_20150623_134547_cell_114.png',
#  'C37BP2_thinF_IMG_20150620_132847a_cell_50.png',
#  'C119P80ThinF_IMG_20151002_124425_cell_121.png',
#  'C128P89ThinF_IMG_20151004_131129_cell_130.png',
#  'C159P120ThinF_IMG_20151115_185541_cell_166.png',
#  'C33P1thinF_IMG_20150619_121300a_cell_46.png',
#  'C122P83ThinF_IMG_20151002_150207_cell_97.png',
#  'C55P16thinF_IMG_20150728_123154_cell_43.png',
#  'C179P140ThinF_IMG_20151127_153852_cell_120.png',
#  'C54P15thinF_IMG_20150728_112938_cell_46.png',
#  'C67P28N_ThinF_IMG_20150819_133000_cell_23.png',
#  'C109P70ThinF_IMG_20150930_103214_cell_14.png',
#  'C210ThinF_IMG_20151029_162605_cell_1.png',
#  'C158P119ThinF_IMG_20151115_181436_cell_118.png',
#  'C50P11thinF_IMG_20150724_114951_cell_51.png',
#  'C81P42ThinF_IMG_20150817_115942_cell_187.png',
#  'C140P101ThinF_IMG_20151005_210207_cell_73.png',
#  'C172P133ThinF_IMG_20151119_154936_cell_224.png',
#  'C148P109ThinF_IMG_20151115_112253_cell_122.png',
#  'C168P129ThinF_IMG_20151118_154651_cell_88.png',
#  'C137P98ThinF_IMG_20151005_163218_cell_63.png',
#  'C148P109ThinF_IMG_20151115_112253_cell_78.png',
#  'C169P130ThinF_IMG_20151119_144354_cell_82.png',
#  'C84P45ThinF_IMG_20150818_104156_cell_39.png',
#  'C106P67ThinF_IMG_20150924_102413_cell_176.png',
#  'C85P46ThinF_IMG_20150820_110040_cell_128.png',
#  'C183P144NThinF_IMG_20151201_223431_cell_78.png',
#  'C140P101ThinF_IMG_20151005_205922_cell_82.png',
#  'C124P85ThinF_IMG_20151002_154846_cell_30.png',
#  'C58P19thinF_IMG_20150802_121847_cell_95.png',
#  'C47P8thin_Original_Motic_IMG_20150714_093715_cell_132.png',
#  'C203ThinF_IMG_20151029_102123_cell_126.png',
#  'C224ThinF_IMG_20151112_112735_cell_179.png',
#  'C70P31_ThinF_IMG_20150819_141730_cell_90.png',
#  'C168P129ThinF_IMG_20151118_161940_cell_42.png',
#  'C163P124ThinF_IMG_20151116_110921_cell_202.png',
#  'C71P32_ThinF_IMG_20150813_162146_cell_120.png',
#  'C95P56ThinF_IMG_20150821_171751_cell_33.png',
#  'C227ThinF_IMG_20151112_135308_cell_203.png',
#  'C236ThinF_IMG_20151127_102115_cell_239.png',
#  'C149P110ThinF_IMG_20151115_114629_cell_157.png',
#  'C142P103ThinF_IMG_20151005_221115_cell_83.png',
#  'C91P52ThinF_IMG_20150821_125154_cell_41.png',
#  'C178P139NThinF_IMG_20151201_154524_cell_132.png',
#  'C117P78ThinF_IMG_20150930_215322_cell_53.png',
#  'C65P26N_ThinF_IMG_20150818_154436_cell_134.png',
#  'C38P3thinF_original_IMG_20150621_112116_cell_1.png',
#  'C151P112ThinF_IMG_20151115_121644_cell_162.png',
#  'C224ThinF_IMG_20151112_111955_cell_255.png',
#  'C117P78ThinF_IMG_20150930_221812_cell_66.png',
#  'C117P78ThinF_IMG_20150930_221927_cell_28.png',
#  'C88P49ThinF_IMG_20150820_151626_cell_10.png',
#  'C103P64ThinF_IMG_20150918_164331_cell_35.png',
#  'C140P101ThinF_IMG_20151005_205406_cell_51.png',
#  'C154P115ThinF_IMG_20151115_141837_cell_176.png',
#  'C176P137NThinF_IMG_20151201_120845_cell_43.png',
#  'C147P108ThinF_IMG_20151115_101317_cell_177.png',
#  'C4thin_original_IMG_20150608_165620_cell_208.png',
#  'C81P42ThinF_IMG_20150817_121113_cell_42.png',
#  'C82P43ThinF_IMG_20150817_124418_cell_98.png',
#  'C215ThinF_IMG_20151106_133116_cell_14.png',
#  'C136P97ThinF_IMG_20151005_143743_cell_98.png',
#  'C54P15thinF_IMG_20150728_102017_cell_91.png',
#  'C162P123ThinF_IMG_20151116_104342_cell_141.png',
#  'C144P105ThinF_IMG_20151015_163142_cell_171.png',
#  'C125P86ThinF_IMG_20151004_102013_cell_61.png',
#  'C180P141NThinF_IMG_20151201_163848_cell_27.png',
#  'C13NThinF_IMG_20150614_131553_cell_126.png',
#  'C69P30N_ThinF_IMG_20150819_135613_cell_55.png',
#  'C47P8thinOriginalOlympusCX21_IMG_20150717_174750_cell_70.png',
#  'C98P59ThinF_IMG_20150917_153311_cell_143.png',
#  'C38P3thinF_original_IMG_20150621_112138_cell_110.png',
#  'C151P112ThinF_IMG_20151115_121942_cell_139.png',
#  'C59P20thinF_IMG_20150803_112802_cell_130.png',
#  'C92P53ThinF_IMG_20150821_151224_cell_48.png',
#  'C113P74ThinF_IMG_20150930_134355_cell_5.png',
#  'C48P9thinF_IMG_20150721_160944_cell_111.png',
#  'C120P81ThinF_IMG_20151002_130715_cell_173.png',
#  'C154P115ThinF_IMG_20151115_141507_cell_191.png',
#  'C218ThinF_IMG_20151106_144001_cell_133.png',
#  'C215ThinF_IMG_20151106_133012_cell_214.png',
#  'C133P94ThinF_IMG_20151004_154351_cell_44.png',
#  'C47P8thin_Original_Motic_IMG_20150714_093806_cell_131.png',
#  'C224ThinF_IMG_20151112_111955_cell_173.png',
#  'C188P149ThinF_IMG_20151203_135433_cell_20.png',
#  'C130P91ThinF_IMG_20151004_141341_cell_19.png',
#  'C208ThinF_IMG_20151029_151017_cell_210.png',
#  'C55P16thinF_IMG_20150728_124508_cell_103.png',
#  'C184P145ThinF_IMG_20151203_103326_cell_2.png',
#  'C122P83ThinF_IMG_20151002_150207_cell_153.png',
#  'C185P146ThinF_IMG_20151203_110448_cell_100.png',
#  'C81P42ThinF_IMG_20150817_120712_cell_74.png',
#  'C50P11thinF_IMG_20150724_120716_cell_10.png',
#  'C168P129ThinF_IMG_20151118_155802_cell_136.png',
#  'C159P120ThinF_IMG_20151115_190002_cell_215.png',
#  'C99P60ThinF_IMG_20150918_140900_cell_44.png',
#  'C188P149ThinF_IMG_20151203_135433_cell_2.png',
#  'C217ThinF_IMG_20151106_142147_cell_29.png',
#  'C164P125ThinF_IMG_20151116_113954_cell_122.png',
#  'C157P118ThinF_IMG_20151115_163759_cell_125.png',
#  'C238NThinF_IMG_20151207_114038_cell_139.png',
#  'C4thin_original_IMG_20150608_165620_cell_194.png',
#  'C116P77ThinF_IMG_20150930_171558_cell_1.png',
#  'C232ThinF_IMG_20151112_154424_cell_138.png',
#  'C129P90ThinF_IMG_20151004_133921_cell_81.png',
#  'C78P39ThinF_IMG_20150606_103459_cell_100.png',
#  'C131P92ThinF_IMG_20151004_151126_cell_58.png',
#  'C159P120ThinF_IMG_20151115_190642_cell_145.png',
#  'C133P94ThinF_IMG_20151004_154919_cell_25.png',
#  'C131P92ThinF_IMG_20151004_145302_cell_89.png',
#  'C93P54ThinF_IMG_20150821_162901_cell_51.png',
#  'C61P22N_ThinF_IMG_20150818_112626_cell_164.png',
#  'C62P23N_ThinF_IMG_20150818_133055_cell_160.png',
#  'C145P106ThinF_IMG_20151016_154921_cell_52.png',
#  'C176P137NThinF_IMG_20151201_122444_cell_7.png',
#  'C72P33_ThinF_IMG_20150815_104307_cell_169.png',
#  'C170P131ThinF_IMG_20151119_120150_cell_49.png',
#  'C166P127ThinF_IMG_20151117_195030_cell_77.png',
#  'C75P36_ThinF_IMG_20150815_163707_cell_33.png',
#  'C54P15thinF_IMG_20150728_112832_cell_183.png',
#  'C165P126ThinF_IMG_20151117_171006_cell_52.png',
#  'C42P5thin_original_IMG_20150623_135251_cell_36.png',
#  'C105P66ThinF_IMG_20150924_095130_cell_148.png',
#  'C218ThinF_IMG_20151106_144337_cell_1.png',
#  'C219ThinF_IMG_20151106_150027_cell_2.png',
#  'C39P4thinF_original_IMG_20150622_110435_cell_41.png',
#  'C79P40ThinF_IMG_20150817_104316_cell_150.png',
#  'C183P144NThinF_IMG_20151201_223431_cell_41.png',
#  'C88P49ThinF_IMG_20150820_151626_cell_60.png',
#  'C218ThinF_IMG_20151106_144337_cell_53.png',
#  'C100P61ThinF_IMG_20150918_145422_cell_86.png',
#  'C33P1thinF_IMG_20150619_115740a_cell_132.png',
#  'C164P125ThinF_IMG_20151116_115149_cell_37.png',
#  'C216ThinF_IMG_20151106_134733_cell_218.png',
#  'C85P46ThinF_IMG_20150820_110143_cell_184.png',
#  'C114P75ThinF_IMG_20150930_150145_cell_11.png',
#  'C141P102ThinF_IMG_20151005_215348_cell_79.png',
#  'C93P54ThinF_IMG_20150821_164024_cell_138.png',
#  'C146P107ThinF_IMG_20151018_135703_cell_18.png',
#  'C60P21thinF_IMG_20150804_105955_cell_31.png',
#  'C48P9thinF_IMG_20150721_160406_cell_181.png',
#  'C119P80ThinF_IMG_20151002_124345_cell_86.png',
#  'C80P41ThinF_IMG_20150817_111544_cell_16.png',
#  'C7NthinF_IMG_20150611_105444_cell_31.png',
#  'C223ThinF_IMG_20151112_104410_cell_164.png',
#  'C235ThinF_IMG_20151112_164625_cell_93.png',
#  'C84P45ThinF_IMG_20150818_101412_cell_57.png',
#  'C54P15thinF_IMG_20150728_105949_cell_151.png',
#  'C119P80ThinF_IMG_20151002_123911_cell_70.png',
#  'C4thin_original_IMG_20150608_165540_cell_52.png',
#  'C90P51ThinF_IMG_20150821_115056_cell_202.png',
#  'C90P51ThinF_IMG_20150821_120044_cell_51.png',
#  'C228ThinF_IMG_20151112_142109_cell_117.png',
#  'C214ThinF_IMG_20151106_114526_cell_13.png',
#  'C79P40ThinF_IMG_20150817_103139_cell_86.png',
#  'C75P36_ThinF_IMG_20150815_163225_cell_108.png',
#  'C90P51ThinF_IMG_20150821_115700_cell_170.png',
#  'C185P146ThinF_IMG_20151203_110448_cell_201.png',
#  'C114P75ThinF_IMG_20150930_150833_cell_73.png',
#  'C173P134NThinF_IMG_20151130_125408_cell_94.png',
#  'C207ThinF_IMG_20151029_143952_cell_229.png',
#  'C104P65ThinF_IMG_20150918_172639_cell_93.png',
#  'C179P140ThinF_IMG_20151127_153436_cell_96.png',
#  'C149P110ThinF_IMG_20151115_115154_cell_31.png',
#  'C89P50ThinF_IMG_20150820_162504_cell_178.png',
#  'C61P22N_ThinF_IMG_20150818_112704_cell_212.png',
#  'C169P130ThinF_IMG_20151119_144354_cell_227.png',
#  'C227ThinF_IMG_20151112_135308_cell_217.png',
#  'C208ThinF_IMG_20151029_155436_cell_27.png',
#  'C37BP2_thinF_IMG_20150620_131423a_cell_10.png',
#  'C49P10thinF_IMG_20150724_102330_cell_59.png',
#  'C212ThinF_IMG_20151106_110411_cell_166.png',
#  'C172P133ThinF_IMG_20151119_155156_cell_89.png',
#  'C60P21thinF_IMG_20150804_105034_cell_82.png',
#  'C116P77ThinF_IMG_20150930_171558_cell_80.png',
#  'C77P38ThinF_IMG_20150602_143524_cell_42.png',
#  'C85P46ThinF_IMG_20150820_110040_cell_40.png',
#  'C210ThinF_IMG_20151029_162357_cell_129.png',
#  'C107P68ThinF_IMG_20150924_221632_cell_11.png',
#  'C80P41ThinF_IMG_20150817_111246_cell_36.png',
#  'C145P106ThinF_IMG_20151016_155051_cell_14.png',
#  'C12NThinF_IMG_20150614_125741_cell_116.png',
#  'C129P90ThinF_IMG_20151004_133538_cell_54.png',
#  'C37BP2_thinF_IMG_20150620_133205a_cell_9.png',
#  'C76P37ThinF_IMG_20150815_172902_cell_159.png',
#  'C54P15thinF_IMG_20150728_112938_cell_32.png',
#  'C219ThinF_IMG_20151106_150314_cell_105.png',
#  'C78P39ThinF_IMG_20150606_104936_cell_147.png',
#  'C214ThinF_IMG_20151106_114910_cell_116.png',
#  'C145P106ThinF_IMG_20151016_155121_cell_83.png',
#  'C178P139NThinF_IMG_20151201_153846_cell_24.png',
#  'C240ThinF_IMG_20151127_115328_cell_157.png',
#  'C118P79ThinF_IMG_20151002_110725_cell_121.png',
#  'C108P69ThinF_IMG_20150924_225004_cell_20.png',
#  'C121P82ThinF_IMG_20151002_132926_cell_52.png',
#  'C74P35_ThinF_IMG_20150815_114555_cell_27.png',
#  'C189P150ThinF_IMG_20151203_141308_cell_1.png',
#  'C73P34_ThinF_IMG_20150815_111422_cell_163.png',
#  'C241NThinF_IMG_20151207_124030_cell_142.png',
#  'C73P34_ThinF_IMG_20150815_111114_cell_25.png',
#  'C109P70ThinF_IMG_20150930_103645_cell_87.png',
#  'C202ThinF_IMG_20151015_152333_cell_30.png',
#  'C159P120ThinF_IMG_20151115_185541_cell_41.png',
#  'C86P47ThinF_IMG_20150820_125057_cell_142.png',
#  'C167P128ReThinF_IMG_20151201_105707_cell_131.png',
#  'C87P48ThinF_IMG_20150820_144714_cell_192.png',
#  'C86P47ThinF_IMG_20150820_123717_cell_203.png',
#  'C179P140ThinF_IMG_20151127_153350_cell_118.png',
#  'C228ThinF_IMG_20151112_142109_cell_244.png',
#  'C218ThinF_IMG_20151106_144001_cell_26.png',
#  'C80P41ThinF_IMG_20150817_110608_cell_33.png',
#  'C159P120ThinF_IMG_20151115_190642_cell_59.png',
#  'C39P4thinF_original_IMG_20150622_111206_cell_10.png',
#  'C46P7ThinF_IMG_20151130_205558_cell_17.png',
#  'C141P102ThinF_IMG_20151005_214338_cell_135.png',
#  'C80P41ThinF_IMG_20150817_110834_cell_42.png',
#  'C83P44ThinF_IMG_20150817_133454_cell_20.png',
#  'C239ThinF_IMG_20151127_113008_cell_1.png',
#  'C157P118ThinF_IMG_20151115_163759_cell_82.png',
#  'C155P116ThinF_IMG_20151115_143156_cell_26.png',
#  'C92P53ThinF_IMG_20150821_150718_cell_1.png',
#  'C86P47ThinF_IMG_20150820_124259_cell_119.png',
#  'C137P98ThinF_IMG_20151005_160122_cell_18.png',
#  'C177P138NThinF_IMG_20151201_143546_cell_7.png',
#  'C88P49ThinF_IMG_20150820_152521_cell_159.png',
#  'C215ThinF_IMG_20151106_133643_cell_18.png',
#  'C72P33_ThinF_IMG_20150815_105033_cell_30.png',
#  'C74P35_ThinF_IMG_20150815_120957_cell_22.png',
#  'C13NThinF_IMG_20150614_131318_cell_125.png',
#  'C225ThinF_IMG_20151112_113836_cell_163.png',
#  'C136P97ThinF_IMG_20151005_141946_cell_78.png',
#  'C236ThinF_IMG_20151127_102546_cell_89.png',
#  'C52P13thinF_IMG_20150725_125213_cell_166.png',
#  'C141P102ThinF_IMG_20151005_214033_cell_93.png',
#  'C79P40ThinF_IMG_20150817_104745_cell_111.png',
#  'C125P86ThinF_IMG_20151004_101929_cell_112.png',
#  'C117P78ThinF_IMG_20150930_220616_cell_53.png',
#  'C233ThinF_IMG_20151112_160635_cell_56.png',
#  'C227ThinF_IMG_20151112_135308_cell_3.png',
#  'C181P142ThinF_IMG_20151127_155722_cell_155.png',
#  'C143P104ThinF_IMG_20151005_230100_cell_134.png',
#  'C39P4thinF_original_IMG_20150622_110435_cell_32.png',
#  'C148P109ThinF_IMG_20151115_112445_cell_191.png',
#  'C103P64ThinF_IMG_20150918_165125_cell_106.png',
#  'C140P101ThinF_IMG_20151005_205406_cell_132.png',
#  'C103P64ThinF_IMG_20150918_165510_cell_14.png',
#  'C122P83ThinF_IMG_20151002_145330_cell_108.png',
#  'C235ThinF_IMG_20151112_164625_cell_68.png',
#  'C79P40ThinF_IMG_20150817_102702_cell_5.png',
#  'C61P22N_ThinF_IMG_20150818_112518_cell_9.png',
#  'C71P32_ThinF_IMG_20150813_161634_cell_128.png',
#  'C42P5thin_original_IMG_20150623_134751_cell_124.png',
#  'C175P136NThinF_IMG_20151127_142326_cell_136.png',
#  'C39P4thinF_original_IMG_20150622_110115_cell_41.png',
#  'C210ThinF_IMG_20151029_162934_cell_248.png',
#  'C49P10thinF_IMG_20150724_103054_cell_33.png',
#  'C212ThinF_IMG_20151106_105941_cell_102.png',
#  'C212ThinF_IMG_20151106_105437_cell_219.png',
#  'C1_thinF_IMG_20150604_104919_cell_164.png',
#  'C141P102ThinF_IMG_20151005_215711_cell_47.png',
#  'C136P97ThinF_IMG_20151005_140646_cell_52.png',
#  'C124P85ThinF_IMG_20151002_154846_cell_139.png',
#  'C55P16thinF_IMG_20150728_123154_cell_29.png',
#  'C214ThinF_IMG_20151106_115440_cell_92.png',
#  'C99P60ThinF_IMG_20150918_141314_cell_81.png',
#  'C152P113ThinF_IMG_20151115_124032_cell_173.png',
#  'C120P81ThinF_IMG_20151002_130150_cell_58.png',
#  'C116P77ThinF_IMG_20150930_172112_cell_44.png',
#  'C115P76ThinF_IMG_20150930_162038_cell_9.png',
#  'C165P126ThinF_IMG_20151117_171006_cell_182.png',
#  'C152P113ThinF_IMG_20151115_124557_cell_39.png',
#  'C148P109ThinF_IMG_20151115_112333_cell_211.png',
#  'C223ThinF_IMG_20151112_103809_cell_41.png',
#  'C136P97ThinF_IMG_20151005_143329_cell_3.png',
#  'C37BP2_thinF_IMG_20150620_133001a_cell_45.png',
#  'C103P64ThinF_IMG_20150918_165510_cell_138.png',
#  'C132P93ThinF_IMG_20151004_151811_cell_63.png',
#  'C93P54ThinF_IMG_20150821_163815_cell_197.png',
#  'C238NThinF_IMG_20151207_114038_cell_192.png',
#  'C66P27N_ThinF_IMG_20150818_164754_cell_95.png',
#  'C174P135NThinF_IMG_20151127_135512_cell_44.png',
#  'C68P29N_ThinF_IMG_20150819_134112_cell_10.png',
#  'C224ThinF_IMG_20151112_111955_cell_121.png',
#  'C121P82ThinF_IMG_20151002_133427_cell_34.png',
#  'C68P29N_ThinF_IMG_20150819_134326_cell_53.png',
#  'C204ThinF_IMG_20151029_112502_cell_166.png',
#  'C236ThinF_IMG_20151127_102428_cell_100.png',
#  'C144P105ThinF_IMG_20151015_163432_cell_133.png',
#  'C37BP2_thinF_IMG_20150620_133238a_cell_36.png',
#  'C93P54ThinF_IMG_20150821_163815_cell_209.png',
#  'C142P103ThinF_IMG_20151005_223257_cell_18.png',
#  'C236ThinF_IMG_20151127_102516_cell_251.png',
#  'C205ThinF_IMG_20151106_151622_cell_97.png',
#  'C51AP12thinF_IMG_20150724_153313_cell_34.png',
#  'C64P25N_ThinF_IMG_20150818_153401_cell_103.png',
#  'C3thin_original_IMG_20150608_162835_cell_28.png',
#  'C7NthinF_IMG_20150611_104824_cell_127.png',
#  'C177P138NThinF_IMG_20151201_143546_cell_89.png',
#  'C133P94ThinF_IMG_20151004_155721_cell_21.png',
#  'C68P29N_ThinF_IMG_20150819_133350_cell_58.png',
#  'C130P91ThinF_IMG_20151004_141504_cell_21.png',
#  'C108P69ThinF_IMG_20150924_224616_cell_163.png',
#  'C141P102ThinF_IMG_20151005_214836_cell_3.png',
#  'C123P84ThinF_IMG_20151002_152330_cell_187.png',
#  'C5NThinF_IMG_20150609_122108_cell_173.png',
#  'C222ThinF_IMG_20151115_151015_cell_117.png',
#  'C104P65ThinF_IMG_20150918_172214_cell_147.png',
#  'C175P136NThinF_IMG_20151127_141428_cell_196.png',
#  'C118P79ThinF_IMG_20151002_105346_cell_38.png',
#  'C207ThinF_IMG_20151029_144033_cell_275.png',
#  'C80P41ThinF_IMG_20150817_111121_cell_54.png',
#  'C75P36_ThinF_IMG_20150815_163147_cell_42.png',
#  'C100P61ThinF_IMG_20150918_144104_cell_21.png',
#  'C218ThinF_IMG_20151106_144143_cell_190.png',
#  'C119P80ThinF_IMG_20151002_122720_cell_13.png',
#  'C72P33_ThinF_IMG_20150815_105033_cell_4.png',
#  'C209ThinF_IMG_20151029_160721_cell_30.png',
#  'C59P20thinF_IMG_20150803_111333_cell_120.png',
#  'C107P68ThinF_IMG_20150924_221632_cell_61.png',
#  'C171P132ThinF_IMG_20151119_153425_cell_170.png',
#  'C150P111ThinF_IMG_20151115_115805_cell_134.png',
#  'C78P39ThinF_IMG_20150606_104426_cell_24.png',
#  'C33P1thinF_IMG_20150619_120804a_cell_65.png',
#  'C236ThinF_IMG_20151127_102428_cell_116.png',
#  'C162P123ThinF_IMG_20151116_104342_cell_7.png',
#  'C218ThinF_IMG_20151106_144001_cell_140.png',
#  'C67P28N_ThinF_IMG_20150819_125901_cell_149.png',
#  'C94P55ThinF_IMG_20150821_165118_cell_56.png',
#  'C83P44ThinF_IMG_20150817_133609_cell_88.png',
#  'C135P96ThinF_IMG_20151005_124031_cell_75.png',
#  'C142P103ThinF_IMG_20151005_221931_cell_57.png',
#  'C117P78ThinF_IMG_20150930_222228_cell_34.png',
#  'C212ThinF_IMG_20151106_110411_cell_91.png',
#  'C171P132ThinF_IMG_20151119_153512_cell_186.png',
#  'C47P8thinOriginalOlympusCX21_IMG_20150717_172748_cell_143.png',
#  'C45P6ThinF_IMG_20151130_155011_cell_49.png',
#  'C109P70ThinF_IMG_20150930_103811_cell_130.png',
#  'C39P4thinF_original_IMG_20150622_111723_cell_73.png',
#  'C223ThinF_IMG_20151112_104708_cell_94.png',
#  'C155P116ThinF_IMG_20151115_143330_cell_152.png',
#  'C139P100ThinF_IMG_20151005_182527_cell_3.png',
#  'C67P28N_ThinF_IMG_20150819_125901_cell_188.png',
#  'C179P140ThinF_IMG_20151127_153521_cell_103.png',
#  'C73P34_ThinF_IMG_20150815_111422_cell_175.png',
#  'C173P134NThinF_IMG_20151130_125408_cell_67.png',
#  'C170P131ThinF_IMG_20151119_120019_cell_11.png',
#  'C142P103ThinF_IMG_20151005_223257_cell_174.png',
#  'C83P44ThinF_IMG_20150817_133355_cell_144.png',
#  'C169P130ThinF_IMG_20151119_143212_cell_11.png',
#  'C166P127ThinF_IMG_20151117_193931_cell_17.png',
#  'C173P134NThinF_IMG_20151130_125501_cell_158.png',
#  'C238NThinF_IMG_20151207_114914_cell_180.png',
#  'C207ThinF_IMG_20151029_143711_cell_82.png',
#  'C56P17thinF_IMG_20150728_160256_cell_59.png',
#  'C53P14thinF_IMG_20150726_120026_cell_121.png',
#  'C228ThinF_IMG_20151112_142730_cell_85.png',
#  'C228ThinF_IMG_20151112_142109_cell_78.png',
#  'C101P62ThinF_IMG_20150923_170344_cell_31.png',
#  'C77P38ThinF_IMG_20150602_143524_cell_126.png',
#  'C150P111ThinF_IMG_20151115_120244_cell_70.png',
#  'C85P46ThinF_IMG_20150820_110143_cell_154.png',
#  'C207ThinF_IMG_20151029_144152_cell_281.png',
#  'C89P50ThinF_IMG_20150820_163347_cell_196.png',
#  'C54P15thinF_IMG_20150728_112938_cell_43.png',
#  'C122P83ThinF_IMG_20151002_144855_cell_86.png',
#  'C80P41ThinF_IMG_20150817_110957_cell_45.png',
#  'C222ThinF_IMG_20151115_151211_cell_153.png',
#  'C207ThinF_IMG_20151029_143952_cell_151.png',
#  'C188P149ThinF_IMG_20151203_134419_cell_40.png',
#  'C55P16thinF_IMG_20150728_124508_cell_11.png',
#  'C72P33_ThinF_IMG_20150815_104045_cell_175.png',
#  'C124P85ThinF_IMG_20151002_154846_cell_127.png',
#  'C168P129ThinF_IMG_20151118_154651_cell_75.png',
#  'C142P103ThinF_IMG_20151005_221900_cell_182.png',
#  'C103P64ThinF_IMG_20150918_164331_cell_153.png',
#  'C51AP12thinF_IMG_20150724_161126_cell_16.png',
#  'C153P114ThinF_IMG_20151115_135746_cell_183.png',
#  'C55P16thinF_IMG_20150728_121151_cell_65.png',
#  'C39P4thinF_original_IMG_20150622_110115_cell_5.png',
#  'C102P63ThinF_IMG_20150918_162051_cell_29.png',
#  'C67P28N_ThinF_IMG_20150819_121456_cell_56.png',
#  'C75P36_ThinF_IMG_20150815_162935_cell_36.png',
#  'C139P100ThinF_IMG_20151005_182527_cell_75.png',
#  'C138P99ThinF_IMG_20151005_170905_cell_148.png',
#  'C105P66ThinF_IMG_20150924_094944_cell_41.png',
#  'C175P136NThinF_IMG_20151127_141428_cell_161.png',
#  'C168P129ThinF_IMG_20151118_160845_cell_4.png',
#  'C223ThinF_IMG_20151112_104708_cell_108.png',
#  'C155P116ThinF_IMG_20151115_143156_cell_126.png',
#  'C221ThinF_IMG_20151106_160022_cell_49.png',
#  'C218ThinF_IMG_20151106_144143_cell_192.png',
#  'C218ThinF_IMG_20151106_143940_cell_183.png',
#  'C216ThinF_IMG_20151106_135653_cell_168.png',
#  'C53P14thinF_IMG_20150726_120600_cell_44.png',
#  'C87P48ThinF_IMG_20150820_144714_cell_22.png',
#  'C65P26N_ThinF_IMG_20150818_154624_cell_99.png',
#  'C177P138NThinF_IMG_20151201_142942_cell_29.png',
#  'C162P123ThinF_IMG_20151116_102751_cell_146.png',
#  'C142P103ThinF_IMG_20151005_223257_cell_119.png',
#  'C46P7ThinF_IMG_20151130_205828_cell_58.png',
#  'C119P80ThinF_IMG_20151002_124345_cell_84.png',
#  'C82P43ThinF_IMG_20150817_124010_cell_123.png',
#  'C179P140ThinF_IMG_20151127_153453_cell_97.png',
#  'C47P8thin_Original_Motic_IMG_20150714_093947_cell_146.png',
#  'C175P136NThinF_IMG_20151127_141253_cell_140.png',
#  'C164P125ThinF_IMG_20151116_113651_cell_105.png',
#  'C123P84ThinF_IMG_20151002_150931_cell_129.png',
#  'C224ThinF_IMG_20151112_112334_cell_108.png',
#  'C141P102ThinF_IMG_20151005_214836_cell_143.png',
#  'C211ThinF_IMG_20151029_164218_cell_16.png',
#  'C87P48ThinF_IMG_20150820_132327_cell_133.png',
#  'C207ThinF_IMG_20151029_143952_cell_167.png',
#  'C83P44ThinF_IMG_20150817_134331_cell_194.png',
#  'C221ThinF_IMG_20151106_155857_cell_60.png',
#  'C165P126ThinF_IMG_20151117_172356_cell_129.png',
#  'C107P68ThinF_IMG_20150924_222630_cell_74.png',
#  'C111P72ThinF_IMG_20150930_113003_cell_16.png',
#  'C140P101ThinF_IMG_20151005_210207_cell_43.png',
#  'C181P142ThinF_IMG_20151127_155722_cell_11.png',
#  'C183P144NThinF_IMG_20151201_223758_cell_109.png',
#  'C159P120ThinF_IMG_20151115_190812_cell_104.png',
#  'C81P42ThinF_IMG_20150817_120524_cell_6.png',
#  'C74P35_ThinF_IMG_20150815_120957_cell_109.png',
#  'C82P43ThinF_IMG_20150817_124010_cell_39.png',
#  'C162P123ThinF_IMG_20151116_104342_cell_113.png',
#  'C116P77ThinF_IMG_20150930_171809_cell_1.png',
#  'C184P145ThinF_IMG_20151203_102543_cell_99.png',
#  'C185P146ThinF_IMG_20151203_110933_cell_81.png',
#  'C49P10thinF_IMG_20150724_103054_cell_114.png',
#  'C102P63ThinF_IMG_20150918_163054_cell_127.png',
#  'C126P87ThinF_IMG_20151004_104408_cell_34.png',
#  'C118P79ThinF_IMG_20151002_104831_cell_83.png',
#  'C156P117ThinF_IMG_20151115_155104_cell_142.png',
#  'C134P95ThinF_IMG_20151005_122449_cell_3.png',
#  'C175P136NThinF_IMG_20151127_141253_cell_47.png',
#  'C94P55ThinF_IMG_20150821_170021_cell_156.png',
#  'C155P116ThinF_IMG_20151115_143156_cell_141.png',
#  'C170P131ThinF_IMG_20151119_120150_cell_85.png',
#  'C213ThinF_IMG_20151106_112759_cell_151.png',
#  'C12NThinF_IMG_20150614_125703_cell_239.png',
#  'C168P129ThinF_IMG_20151118_160845_cell_135.png',
#  'C114P75ThinF_IMG_20150930_150145_cell_77.png',
#  'C114P75ThinF_IMG_20150930_150733_cell_116.png',
#  'C102P63ThinF_IMG_20150918_162511_cell_163.png',
#  'C37BP2_thinF_IMG_20150620_132847a_cell_7.png',
#  'C240ThinF_IMG_20151127_115545_cell_6.png',
#  'C13NThinF_IMG_20150614_131617_cell_212.png',
#  'C58P19thinF_IMG_20150802_122520_cell_123.png',
#  'C87P48ThinF_IMG_20150820_144855_cell_64.png',
#  'C213ThinF_IMG_20151106_112603_cell_41.png',
#  'C187P148NThinF_IMG_20151203_152841_cell_145.png',
#  'C51AP12thinF_IMG_20150724_155557_cell_37.png',
#  'C231ThinF_IMG_20151112_152234_cell_207.png',
#  'C214ThinF_IMG_20151106_115440_cell_135.png',
#  'C179P140ThinF_IMG_20151127_153819_cell_43.png',
#  'C85P46ThinF_IMG_20150820_105748_cell_123.png',
#  'C216ThinF_IMG_20151106_134931_cell_117.png',
#  'C57P18thinF_IMG_20150729_110305_cell_96.png',
#  'C177P138NThinF_IMG_20151201_143546_cell_42.png',
#  'C130P91ThinF_IMG_20151004_142951_cell_102.png',
#  'C73P34_ThinF_IMG_20150815_111114_cell_97.png',
#  'C182P143NThinF_IMG_20151201_171950_cell_148.png',
#  'C120P81ThinF_IMG_20151002_130407_cell_59.png',
#  'C70P31_ThinF_IMG_20150813_130510_cell_67.png',
#  'C224ThinF_IMG_20151112_112834_cell_87.png',
#  'C119P80ThinF_IMG_20151002_122720_cell_147.png',
#  'C202ThinF_IMG_20151015_151254_cell_41.png',
#  'C150P111ThinF_IMG_20151115_115922_cell_24.png',
#  'C69P30N_ThinF_IMG_20150819_140652_cell_158.png',
#  'C142P103ThinF_IMG_20151005_223257_cell_69.png',
#  'C63P24N_ThinF_IMG_20150818_143757_cell_110.png',
#  'C160P121ThinF_IMG_20151116_093109_cell_99.png',
#  'C53P14thinF_IMG_20150726_120600_cell_52.png',
#  'C120P81ThinF_IMG_20151002_130715_cell_18.png',
#  'C52P13thinF_IMG_20150725_123938_cell_137.png',
#  'C47P8thin_Original_Motic_IMG_20150714_094054_cell_21.png',
#  'C177P138NThinF_IMG_20151201_142846_cell_5.png',
#  'C149P110ThinF_IMG_20151115_114629_cell_241.png',
#  'C102P63ThinF_IMG_20150918_161826_cell_154.png',
#  'C136P97ThinF_IMG_20151005_144727_cell_93.png',
#  'C3thin_original_IMG_20150608_162922_cell_184.png',
#  'C50P11thinF_IMG_20150724_115603_cell_117.png',
#  'C91P52ThinF_IMG_20150821_124739_cell_50.png',
#  'C238NThinF_IMG_20151207_114653_cell_126.png',
#  'C87P48ThinF_IMG_20150820_132514_cell_110.png',
#  'C68P29N_ThinF_IMG_20150819_134504_cell_76.png',
#  'C80P41ThinF_IMG_20150817_111121_cell_83.png',
#  'C99P60ThinF_IMG_20150918_141314_cell_65.png',
#  'C78P39ThinF_IMG_20150606_104936_cell_117.png',
#  'C66P27N_ThinF_IMG_20150818_164408_cell_68.png',
#  'C187P148NThinF_IMG_20151203_154249_cell_1.png',
#  'C225ThinF_IMG_20151112_113915_cell_128.png',
#  'C234ThinF_IMG_20151112_163036_cell_222.png',
#  'C163P124ThinF_IMG_20151116_110921_cell_132.png',
#  'C182P143NThinF_IMG_20151201_171905_cell_32.png',
#  'C64P25N_ThinF_IMG_20150818_152613_cell_165.png',
#  'C3thin_original_IMG_20150608_163047_cell_147.png',
#  'C180P141NThinF_IMG_20151201_163702_cell_162.png',
#  'C79P40ThinF_IMG_20150817_104745_cell_142.png',
#  'C133P94ThinF_IMG_20151004_154158_cell_40.png',
#  'C82P43ThinF_IMG_20150817_124418_cell_48.png',
#  'C47P8thin_Original_Motic_IMG_20150714_093947_cell_58.png',
#  'C220ThinF_IMG_20151106_153947_cell_231.png',
#  'C226ThinF_IMG_20151112_131731_cell_34.png',
#  'C63P24N_ThinF_IMG_20150818_143544_cell_64.png',
#  'C208ThinF_IMG_20151029_155827_cell_157.png',
#  'C33P1thinF_IMG_20150619_114756a_cell_81.png',
#  'C186P147NThinF_IMG_20151203_150322_cell_110.png',
#  'C124P85ThinF_IMG_20151002_155026_cell_19.png',
#  'C229ThinF_IMG_20151112_144222_cell_162.png',
#  'C85P46ThinF_IMG_20150820_105301_cell_80.png',
#  'C37BP2_thinF_IMG_20150620_132440a_cell_54.png',
#  'C128P89ThinF_IMG_20151004_131753_cell_49.png',
#  'C91P52ThinF_IMG_20150821_125154_cell_48.png',
#  'C137P98ThinF_IMG_20151005_163901_cell_51.png',
#  'C145P106ThinF_IMG_20151016_154844_cell_117.png',
#  'C240ThinF_IMG_20151127_115223_cell_194.png',
#  'C60P21thinF_IMG_20150803_144510_cell_130.png',
#  'C75P36_ThinF_IMG_20150815_163742_cell_17.png',
#  'C140P101ThinF_IMG_20151005_211735_cell_111.png',
#  'C74P35_ThinF_IMG_20150815_114153_cell_100.png',
#  'C103P64ThinF_IMG_20150918_164250_cell_39.png',
#  'C141P102ThinF_IMG_20151005_214338_cell_119.png',
#  'C120P81ThinF_IMG_20151002_130150_cell_130.png',
#  'C105P66ThinF_IMG_20150924_095034_cell_29.png',
#  'C87P48ThinF_IMG_20150820_144714_cell_195.png',
#  'C56P17thinF_IMG_20150728_160438_cell_52.png',
#  'C149P110ThinF_IMG_20151115_115154_cell_34.png',
#  'C111P72ThinF_IMG_20150930_113610_cell_99.png',
#  'C49P10thinF_IMG_20150724_102843_cell_84.png',
#  'C74P35_ThinF_IMG_20150815_114401_cell_35.png',
#  'C42P5thin_original_IMG_20150623_134426_cell_127.png',
#  'C39P4thinF_original_IMG_20150622_111723_cell_39.png',
#  'C220ThinF_IMG_20151106_154016_cell_107.png',
#  'C76P37ThinF_IMG_20150815_171214_cell_177.png',
#  'C148P109ThinF_IMG_20151115_112445_cell_237.png',
#  'C137P98ThinF_IMG_20151005_160918_cell_47.png',
#  'C173P134NThinF_IMG_20151130_120046_cell_145.png',
#  'C227ThinF_IMG_20151112_135509_cell_143.png',
#  'C94P55ThinF_IMG_20150821_170403_cell_53.png',
#  'C80P41ThinF_IMG_20150817_111246_cell_59.png',
#  'C174P135NThinF_IMG_20151127_135311_cell_65.png',
#  'C170P131ThinF_IMG_20151119_115918_cell_107.png',
#  'C55P16thinF_IMG_20150728_121350_cell_151.png',
#  'C51AP12thinF_IMG_20150724_155947_cell_82.png',
#  'C146P107ThinF_IMG_20151018_134554_cell_38.png',
#  'C46P7ThinF_IMG_20151130_205558_cell_20.png',
#  'C146P107ThinF_IMG_20151018_135846_cell_35.png',
#  'C240ThinF_IMG_20151127_115223_cell_120.png',
#  'C107P68ThinF_IMG_20150924_222630_cell_23.png',
#  'C77P38ThinF_IMG_20150601_155642_cell_88.png',
#  'C104P65ThinF_IMG_20150918_172639_cell_34.png',
#  'C49P10thinF_IMG_20150724_102330_cell_42.png',
#  'C90P51ThinF_IMG_20150821_115310_cell_196.png',
#  'C227ThinF_IMG_20151112_135308_cell_46.png',
#  'C78P39ThinF_IMG_20150606_103630_cell_46.png',
#  'C208ThinF_IMG_20151029_155436_cell_48.png',
#  'C57P18thinF_IMG_20150729_110457_cell_9.png',
#  'C125P86ThinF_IMG_20151004_102132_cell_100.png',
#  'C42P5thin_original_IMG_20150623_135251_cell_20.png',
#  'C54P15thinF_IMG_20150728_112832_cell_176.png',
#  'C217ThinF_IMG_20151106_141649_cell_88.png',
#  'C225ThinF_IMG_20151112_113803_cell_134.png',
#  'C114P75ThinF_IMG_20150930_150555_cell_78.png',
#  'C129P90ThinF_IMG_20151004_133244_cell_76.png',
#  'C97P58ThinF_IMG_20150917_145555_cell_88.png',
#  'C149P110ThinF_IMG_20151115_114629_cell_28.png',
#  'C1_thinF_IMG_20150604_105100_cell_186.png',
#  'C162P123ThinF_IMG_20151116_104736_cell_96.png',
#  'C216ThinF_IMG_20151106_134733_cell_56.png',
#  'C223ThinF_IMG_20151112_104240_cell_122.png',
#  'C104P65ThinF_IMG_20150918_171154_cell_3.png',
#  'C129P90ThinF_IMG_20151004_133703_cell_10.png',
#  'C112P73ThinF_IMG_20150930_131605_cell_146.png',
#  'C74P35_ThinF_IMG_20150815_120712_cell_33.png',
#  'C105P66ThinF_IMG_20150924_095130_cell_58.png',
#  'C120P81ThinF_IMG_20151002_130407_cell_102.png',
#  'C73P34_ThinF_IMG_20150815_112246_cell_92.png',
#  'C136P97ThinF_IMG_20151005_144727_cell_82.png',
#  'C148P109ThinF_IMG_20151115_112445_cell_29.png',
#  'C234ThinF_IMG_20151112_162940_cell_193.png',
#  'C47P8thin_Original_Motic_IMG_20150714_094054_cell_70.png',
#  'C67P28N_ThinF_IMG_20150819_115955_cell_107.png',
#  'C82P43ThinF_IMG_20150817_124418_cell_138.png',
#  'C134P95ThinF_IMG_20151005_121048_cell_109.png',
#  'C53P14thinF_IMG_20150726_115046_cell_1.png',
#  'C156P117ThinF_IMG_20151115_154435_cell_206.png',
#  'C63P24N_ThinF_IMG_20150818_143757_cell_64.png',
#  'C3thin_original_IMG_20150608_163047_cell_236.png',
#  'C53P14thinF_IMG_20150726_114404_cell_57.png',
#  'C66P27N_ThinF_IMG_20150818_163419_cell_182.png',
#  'C99P60ThinF_IMG_20150918_141314_cell_79.png',
#  'C127P88ThinF_IMG_20151004_111651_cell_99.png',
#  'C182P143NThinF_IMG_20151201_172524_cell_92.png',
#  'C78P39ThinF_IMG_20150606_104936_cell_144.png',
#  'C71P32_ThinF_IMG_20150813_163655_cell_140.png',
#  'C223ThinF_IMG_20151112_104118_cell_252.png',
#  'C1_thinF_IMG_20150604_104722_cell_15.png',
#  'C74P35_ThinF_IMG_20150815_113951_cell_98.png',
#  'C81P42ThinF_IMG_20150817_120712_cell_57.png',
#  'C72P33_ThinF_IMG_20150815_104307_cell_135.png',
#  'C223ThinF_IMG_20151112_104410_cell_122.png',
#  'C89P50ThinF_IMG_20150820_162504_cell_59.png',
#  'C153P114ThinF_IMG_20151115_135639_cell_260.png',
#  'C68P29N_ThinF_IMG_20150819_134326_cell_91.png',
#  'C218ThinF_IMG_20151106_144143_cell_91.png',
#  'C185P146ThinF_IMG_20151203_110817_cell_29.png',
#  ...]

# %%
uninfected_cell = train_path + "uninfected/" + "C149P110ThinF_IMG_20151115_114629_cell_75.png"
plt.imshow(imread(uninfected_cell))

# %%
dim1 = []
dim2 = []

for image_filename in os.listdir(test_path + "uninfected"):
    img = imread(test_path + "uninfected/" + image_filename)
    d1, d2, colors = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
sns.jointplot([dim1, dim2])

# %%
np.mean(dim1)
# Out:
# 130.92538461538462

# %%
np.mean(dim2)
# Out:
# 130.75

# %% [markdown]
# # CNN: (2) Data Processing

# %%
image_shape = (130,130,3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator 

help(ImageDataGenerator)
# Out:
# Help on class ImageDataGenerator in module keras.src.legacy.preprocessing.image:
#
# class ImageDataGenerator(builtins.object)
#  |  ImageDataGenerator(featurewise_center=False, samplewise_center=False, featurewise_std_normalization=False, samplewise_std_normalization=False, zca_whitening=False, zca_epsilon=1e-06, rotation_range=0, width_shift_range=0.0, height_shift_range=0.0, brightness_range=None, shear_range=0.0, zoom_range=0.0, channel_shift_range=0.0, fill_mode='nearest', cval=0.0, horizontal_flip=False, vertical_flip=False, rescale=None, preprocessing_function=None, data_format=None, validation_split=0.0, interpolation_order=1, dtype=None)
#  |
#  |  DEPRECATED.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, featurewise_center=False, samplewise_center=False, featurewise_std_normalization=False, samplewise_std_normalization=False, zca_whitening=False, zca_epsilon=1e-06, rotation_range=0, width_shift_range=0.0, height_shift_range=0.0, brightness_range=None, shear_range=0.0, zoom_range=0.0, channel_shift_range=0.0, fill_mode='nearest', cval=0.0, horizontal_flip=False, vertical_flip=False, rescale=None, preprocessing_function=None, data_format=None, validation_split=0.0, interpolation_order=1, dtype=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  apply_transform(self, x, transform_parameters)
#  |      Applies a transformation to an image according to given parameters.
#  |
#  |      Args:
#  |          x: 3D tensor, single image.
#  |          transform_parameters: Dictionary with string - parameter pairs
#  |              describing the transformation.
#  |              Currently, the following parameters
#  |              from the dictionary are used:
#  |              - `'theta'`: Float. Rotation angle in degrees.
#  |              - `'tx'`: Float. Shift in the x direction.
#  |              - `'ty'`: Float. Shift in the y direction.
#  |              - `'shear'`: Float. Shear angle in degrees.
#  |              - `'zx'`: Float. Zoom in the x direction.
#  |              - `'zy'`: Float. Zoom in the y direction.
#  |              - `'flip_horizontal'`: Boolean. Horizontal flip.
#  |              - `'flip_vertical'`: Boolean. Vertical flip.
#  |              - `'channel_shift_intensity'`: Float. Channel shift intensity.
#  |              - `'brightness'`: Float. Brightness shift intensity.
#  |
#  |      Returns:
#  |          A transformed version of the input (same shape).
#  |
#  |  fit(self, x, augment=False, rounds=1, seed=None)
#  |      Fits the data generator to some sample data.
#  |
#  |      This computes the internal data stats related to the
#  |      data-dependent transformations, based on an array of sample data.
#  |
#  |      Only required if `featurewise_center` or
#  |      `featurewise_std_normalization` or `zca_whitening`
#  |      are set to `True`.
#  |
#  |      When `rescale` is set to a value, rescaling is applied to
#  |      sample data before computing the internal data stats.
#  |
#  |      Args:
#  |          x: Sample data. Should have rank 4.
#  |           In case of grayscale data,
#  |           the channels axis should have value 1, in case
#  |           of RGB data, it should have value 3, and in case
#  |           of RGBA data, it should have value 4.
#  |          augment: Boolean (default: False).
#  |              Whether to fit on randomly augmented samples.
#  |          rounds: Int (default: 1).
#  |              If using data augmentation (`augment=True`),
#  |              this is how many augmentation passes over the data to use.
#  |          seed: Int (default: None). Random seed.
#  |
#  |  flow(self, x, y=None, batch_size=32, shuffle=True, sample_weight=None, seed=None, save_to_dir=None, save_prefix='', save_format='png', ignore_class_split=False, subset=None)
#  |
#  |  flow_from_dataframe(self, dataframe, directory=None, x_col='filename', y_col='class', weight_col=None, target_size=(256, 256), color_mode='rgb', classes=None, class_mode='categorical', batch_size=32, shuffle=True, seed=None, save_to_dir=None, save_prefix='', save_format='png', subset=None, interpolation='nearest', validate_filenames=True, **kwargs)
#  |
#  |  flow_from_directory(self, directory, target_size=(256, 256), color_mode='rgb', classes=None, class_mode='categorical', batch_size=32, shuffle=True, seed=None, save_to_dir=None, save_prefix='', save_format='png', follow_links=False, subset=None, interpolation='nearest', keep_aspect_ratio=False)
#  |
#  |  get_random_transform(self, img_shape, seed=None)
#  |      Generates random parameters for a transformation.
#  |
#  |      Args:
#  |          img_shape: Tuple of integers.
#  |              Shape of the image that is transformed.
#  |          seed: Random seed.
#  |
#  |      Returns:
#  |          A dictionary containing randomly chosen parameters describing the
#  |          transformation.
#  |
#  |  random_transform(self, x, seed=None)
#  |      Applies a random transformation to an image.
#  |
#  |      Args:
#  |          x: 3D tensor, single image.
#  |          seed: Random seed.
#  |
#  |      Returns:
#  |          A randomly transformed version of the input (same shape).
#  |
#  |  standardize(self, x)
#  |      Applies the normalization configuration in-place to a batch of
#  |      inputs.
#  |
#  |      `x` is changed in-place since the function is mainly used internally
#  |      to standardize images and feed them to your network. If a copy of `x`
#  |      would be created instead it would have a significant performance cost.
#  |      If you want to apply this method without changing the input in-place
#  |      you can call the method creating a copy before:
#  |
#  |      standardize(np.copy(x))
#  |
#  |      Args:
#  |          x: Batch of inputs to be normalized.
#  |
#  |      Returns:
#  |          The inputs, normalized.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
image_gen = ImageDataGenerator(rotation_range=20, width_shift_range=0.1, height_shift_range=0.1, shear_range=0.1,
                               zoom_range=0.1, horizontal_flip=True, fill_mode='nearest')

# %%
plt.imshow(imread(uninfected_cell))
plt.imshow(imread(para_cell))
para_img = imread(para_cell)

# %%
plt.imshow(image_gen.random_transform(para_img))

# %%
image_gen.flow_from_directory(train_path)
# Out:
# Found 24958 images belonging to 2 classes.

# %% [markdown]
# # CNNs: (3) Creating the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape = image_shape, activation='relu'))
model.add(MaxPool2D(pool_size = (2,2)))

model.add(Conv2D(filters=32, kernel_size=(3,3), input_shape = image_shape, activation='relu'))
model.add(MaxPool2D(pool_size = (2,2)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=image_shape, activation="relu"))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# /home/user/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 62, 62, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 29, 29, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       802,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 822,465 (3.14 MB)
#  Trainable params: 822,465 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience =  2)

batch_size=16

# %%
train_image_gen = image_gen.flow_from_directory(
    train_path, target_size=image_shape[:2], color_mode="rgb", batch_size=batch_size,
    class_mode= 'binary'
)
# Out:
# Found 24958 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory(
    test_path,
    target_size=image_shape[:2],
    color_mode="rgb",
    batch_size=batch_size,
    class_mode="binary",
    shuffle=False
)
# Out:
# Found 2600 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'parasitized': 0, 'uninfected': 1}

# %%
results=model.fit(train_image_gen, epochs=20, validation_data = test_image_gen,
                            callbacks = [early_stop])
# Out:
# Epoch 1/20
# /home/user/.local/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 398s 254ms/step - accuracy: 0.7334 - loss: 1.1786 - val_accuracy: 0.9165 - val_loss: 0.2484
# Epoch 2/20
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 398s 255ms/step - accuracy: 0.9191 - loss: 0.2580 - val_accuracy: 0.9258 - val_loss: 0.2284
# Epoch 3/20
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 295s 189ms/step - accuracy: 0.9306 - loss: 0.2172 - val_accuracy: 0.9400 - val_loss: 0.1938
# Epoch 4/20
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 285s 182ms/step - accuracy: 0.9407 - loss: 0.1912 - val_accuracy: 0.9419 - val_loss: 0.1804
# Epoch 5/20
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 312s 200ms/step - accuracy: 0.9445 - loss: 0.1843 - val_accuracy: 0.9381 - val_loss: 0.1832
# Epoch 6/20
# 1560/1560 ━━━━━━━━━━━━━━━━━━━━ 275s 176ms/step - accuracy: 0.9439 - loss: 0.1802 - val_accuracy: 0.9450 - val_loss: 0.1813

# %%
model.history.history
# Out:
# {'accuracy': [0.8426556587219238,
#   0.919745147228241,
#   0.934770405292511,
#   0.9402195811271667,
#   0.9447471499443054,
#   0.9460293054580688],
#  'loss': [0.47976264357566833,
#   0.2471495270729065,
#   0.2095775455236435,
#   0.19094611704349518,
#   0.18087032437324524,
#   0.1742890328168869],
#  'val_accuracy': [0.9165384769439697,
#   0.9257692098617554,
#   0.9399999976158142,
#   0.9419230818748474,
#   0.938076913356781,
#   0.9449999928474426],
#  'val_loss': [0.2483942061662674,
#   0.2284063696861267,
#   0.1938125342130661,
#   0.18038518726825714,
#   0.18324460089206696,
#   0.18129053711891174]}
